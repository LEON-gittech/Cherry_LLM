# %%
import torch

# %%
data = torch.load("/mnt/bn/data-tns-live-llm/leon/datasets/fed_data/pre_exp_data.pt")
print(len(data))
# Out:
# 407318

# %%
print(data[0])
# Out:
# {'ppl': [0, tensor(15.6250, dtype=torch.bfloat16), tensor(12., dtype=torch.bfloat16)], 'token_loss': [[], [11.5, 1.9140625, 16.125, 6.875, 2.875, 0.00182342529296875, 5.6875, 6.875, 0.953125, 5.75, 4.15625, 4.875, 2.203125, 3.046875, 0.53125, 1.1015625, 13.0, 6.25, 2.703125, 12.3125, 5.96875, 0.3046875, 2.8125, 0.1650390625, 7.3125, 0.244140625, 0.038818359375, 4.375, 13.0, 0.890625, 1.2421875, 9.3125, 0.484375, 1.890625, 0.1005859375, 8.5625, 3.78125, 0.25390625, 11.0, 0.1357421875, 2.78125, 2.015625, 7.96875, 0.236328125, 0.94140625, 0.29296875, 0.94140625, 9.0, 0.1533203125, 0.2294921875, 2.1875, 3.890625, 3.046875, 1.8984375, 4.8125, 1.359375, 3.53125, 0.0106201171875, 0.90234375, 2.609375, 0.040283203125, 1.8046875, 7.0, 0.05615234375, 0.012451171875, 0.025634765625, 0.1201171875, 0.1435546875, 0.330078125, 0.8125, 0.875, 0.6328125, 0.45703125, 7.8125, 0.01165771484375, 0.0810546875, 0.00015354156494140625, 2.875, 2.0625, 0.671875, 11.0, 0.0140380859375, 0.005401611328125, 10.0,
# ...
